# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 484330      3993    Sri Lanka    Australia  19.3     1                0
# 484331      3993    Sri Lanka    Australia  19.4     0                0
# 484332      3993    Sri Lanka    Australia  19.5     0      DM de Silva
# 484333      3993    Sri Lanka    Australia  19.6     2                0
# 484334      3993    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id                0
# batting_team            0
# bowling_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                14771
# venue                   0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        7077
# Sharjah Cricket Stadium                    2364
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city']=cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 484330      3993    Sri Lanka    Australia  19.3     1                0
# 484331      3993    Sri Lanka    Australia  19.4     0                0
# 484332      3993    Sri Lanka    Australia  19.5     0      DM de Silva
# 484333      3993    Sri Lanka    Australia  19.6     2                0
# 484334      3993    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 484330      3993    Sri Lanka    Australia  19.3     1                0
# 484331      3993    Sri Lanka    Australia  19.4     0                0
# 484332      3993    Sri Lanka    Australia  19.5     0      DM de Silva
# 484333      3993    Sri Lanka    Australia  19.6     2                0
# 484334      3993    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')  # converts strings to numbers, invalids become NaN
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2891478797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')  # converts strings to numbers, invalids become NaN
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2891478797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 484330      3993    Sri Lanka    Australia  19.3     1                0
# 484331      3993    Sri Lanka    Australia  19.4     0                0
# 484332      3993    Sri Lanka    Australia  19.5     0      DM de Silva
# 484333      3993    Sri Lanka    Australia  19.6     2                0
# 484334      3993    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# ...

# %%
# Step 1: Convert to 0/1 (wicket fell or not)
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)

# Step 2: Ensure it's integer
df['player_dismissed'] = df['player_dismissed'].astype(int)

# Step 3: Cumulative sum per match
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# Step 4: Wickets left = 10 - number of players out
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\1254253637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\1254253637.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype(int)
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\1254253637.py:8: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                 0
# 1              1    Australia    Sri Lanka   0.2     0                 0
# 2              1    Australia    Sri Lanka   0.3     1                 0
# 3              1    Australia    Sri Lanka   0.4     2                 0
# 4              1    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 484330      3993    Sri Lanka    Australia  19.3     1                 8
# 484331      3993    Sri Lanka    Australia  19.4     0                 8
# 484332      3993    Sri Lanka    Australia  19.5     0                 9
# 484333      3993    Sri Lanka    Australia  19.6     2                 9
# 484334      3993    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                 0
# 1              1    Australia    Sri Lanka   0.2     0                 0
# 2              1    Australia    Sri Lanka   0.3     1                 0
# 3              1    Australia    Sri Lanka   0.4     2                 0
# 4              1    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 484330      3993    Sri Lanka    Australia  19.3     1                 8
# 484331      3993    Sri Lanka    Australia  19.4     0                 8
# 484332      3993    Sri Lanka    Australia  19.5     0                 9
# 484333      3993    Sri Lanka    Australia  19.6     2                 9
# 484334      3993    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()

last_five = []

for match_id in match_ids:
    match_df = groups.get_group(match_id).copy()

    # Ensure data is sorted by delivery order
    match_df = match_df.sort_values(by='ball').reset_index(drop=True)

    # Apply rolling sum ONLY on 'runs' column with default min_periods=30
    rolling_runs = match_df['runs'].rolling(window=30).sum()

    # Append to final list
    last_five.extend(rolling_runs.tolist())

# %%
last_five
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  42.0,
#  43.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  39.0,
#  38.0,
#  39.0,
#  38.0,
#  39.0,
#  40.0,
#  37.0,
#  41.0,
#  42.0,
#  42.0,
#  44.0,
#  44.0,
#  40.0,
#  39.0,
#  37.0,
#  35.0,
#  31.0,
#  27.0,
#  26.0,
#  31.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  31.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  39.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  44.0,
#  39.0,
#  43.0,
#  45.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  53.0,
#  53.0,
#  53.0,
# ...

# %%
df['last_five'] = last_five
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\786792159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df.drop(columns=['last_30_runs'],inplace=True)
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\3636832876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['last_30_runs'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                 0
# 1              1    Australia    Sri Lanka   0.2     0                 0
# 2              1    Australia    Sri Lanka   0.3     1                 0
# 3              1    Australia    Sri Lanka   0.4     2                 0
# 4              1    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 484330      3993    Sri Lanka    Australia  19.3     1                 8
# 484331      3993    Sri Lanka    Australia  19.4     0                 8
# 484332      3993    Sri Lanka    Australia  19.5     0                 9
# 484333      3993    Sri Lanka    Australia  19.6     2                 9
# 484334      3993    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#         match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0              1     168    Australia    Sri Lanka   0.1       0
# 1              1     168    Australia    Sri Lanka   0.2       0
# 2              1     168    Australia    Sri Lanka   0.3       1
# 3              1     168    Australia    Sri Lanka   0.4       2
# 4              1     168    Australia    Sri Lanka   0.5       0
# ...          ...     ...          ...          ...   ...     ...
# 226458      3993     128    Sri Lanka    Australia  19.3       1
# 226459      3993     128    Sri Lanka    Australia  19.4       0
# 226460      3993     128    Sri Lanka    Australia  19.5       0
# 226461      3993     128    Sri Lanka    Australia  19.6       2
# 226462      3993     128    Sri Lanka    Australia  19.7       1
#
#         player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                      0  Melbourne              0    0       1             1
# ...

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\jeetm\AppData\Local\Temp\ipykernel_2420\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#           batting_team            bowling_team        city  current_score  \
# 7752     Gujarat Lions  Rising Pune Supergiant        Pune             68
# 30168  Kings XI Punjab        Rajasthan Royals  Chandigarh            107
#
#        balls_left  wickets_left       crr  last_five  runs_x
# 7752           76             9  9.272727       52.0     161
# 30168          38             8  7.829268       40.0     182

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
# !pip install xgboost
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/150.0 MB 728.2 kB/s eta 0:03:26
#    ---------------------------------------- 0.8/150.0 MB 729.2 kB/s eta 0:03:25
#    ---------------------------------------- 0.8/150.0 MB 729.2 kB/s eta 0:03:25
#    ---------------------------------------- 1.0/150.0 MB 729.5 kB/s eta 0:03:25
#    ---------------------------------------- 1.3/150.0 MB 762.6 kB/s eta 0:03:15
#    ---------------------------------------- 1.3/150.0 MB 762.6 kB/s eta 0:03:15
#    ---------------------------------------- 1.6/150.0 MB 769.7 kB/s eta 0:03:13
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9838152527809143
# 2.132392168045044

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))
